# %% [markdown]
# # Übungsaufgaben zu Statistik
# ## Aufgabe 1
# Mit Hilfe von np.random.normal können Zufallszahlen in Form einer Normalverteilung erzeugt werden. Hierzu muss der Methode neben dem Mittelwert die Varianz(Sigma²) sowie die Stichprobengröße übergeben werden.
#
# a) Erstellen Sie jeweils ein Array mit 1000,10000 und 50000 Elementen mit dem Mittelwert 50 und der Varianz(Sigma²) von 5.
#
# Link zur Doku: https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# b) Geben Sie anschließend die Werte in einem Histogramm untereinander aus. Die Histogramme sollen 60 Spalten besitzen.
#
# Link zur Doku: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

# %% [markdown]
# Mit Numpy können natürlich auch Mittelwerte und die Standardabweichung berechnet werden.
#
# c) Berechnen Sie den Mittelwert die Varianz sowie die Standardabweichung für 50000 Elemente
#
# Link zur Doku:
# https://numpy.org/doc/stable/reference/generated/numpy.mean.html
# https://numpy.org/doc/stable/reference/generated/numpy.var.html
# https://numpy.org/doc/stable/reference/generated/numpy.std.html

# %%
# Out:
# Mittelwert:  49.95192663393953
# Varianz:  25.128720106416633
# Standardabweichung:  5.01285548429402

# %% [markdown]
# Manchmal möchte man sich auch die Funktion der Normalverteilung in einem Graph anzeigen lassen.
# Die Funktionsgleichung für die Normalverteilung lautet:
#
# ![image.png](attachment:image.png)
#
# d) Erstellen Sie eine Normalverteilung (Standardnormal) mit dem Mittelwert 0, der Varianz sigma²=0.1 und zeichnen Sie die Verteilung anschließend in einem Histogramm mit 30 Balken. Stellen Sie die density zudem auf True
#
# e) Erweitern Sie anschließend das Histogramm um die Funktion der Normalverteilung. Die x-Werte bekommen Sie als Rückgabewert(Bins) beim Aufruf der Methode plt.hist.
#
# Link zur Doku:
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html
