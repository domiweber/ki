# %%
import numpy as np
import array

#Listen
my_list = [True, "Hello", 42.0, 420, None]
print([type(val) for val in my_list])           # mit type(val) kann man sich den Datentyp ausgeben lassen

#Array
my_array_range = list(range(10))
my_array = array.array('i', my_array_range)     #'i' gibt den Datentyp an
print(my_array)

#Numpy Array
def array_info(array: np.ndarray) -> None:
    print(f"ndim: {array.ndim}")                #Gibt die Dimension zurück
    print(f"shape: {array.shape}")              #Gibt den Shape zurück
    print(f"size: {array.size}")                #Gibt die Anzahl an Daten im Array zurück
    print(f"dtype: {array.dtype}")              #Gibt den Array-Datentyp zurück
    print(f"values:\n{array}\n")                #Gibt das Array aus
my_np_array = np.array([1, 4, 2, 5, 3])
array_info(my_np_array)

#Nullmatrix
my_np_array = np.zeros(shape=(10,10), dtype=int)

#Einsmatrix
my_np_array = np.ones(shape=(3, 5), dtype=float)

#Matrix mit gleichen Komponenten
my_np_array = np.full(shape=(3, 5), fill_value=3.14)

#Matrix/Vektor mit Start, Stopwert und Schrittweite
my_np_array = np.arange(start=0, stop=20, step=2)

#Matrix/Vektor mit Start, Stop und Anzahl der Elemetne zwischen Start und Stop
my_np_array = np.linspace(start=0, stop=1, num=5)

#Einheitsmatrix
my_np_array = np.eye(N=3)

#Diagonalmatrix
my_np_array = np.diag([1, 2, 3])

#Matrix mit Zufallszahl in einem Wertebereich
my_np_array = np.random.randint(low=0, high=10, size=(3, 3))

#Matrix mit Reeller Zufallszahl
my_np_array = np.random.random(size=(3, 3))

np.random.seed(0)                               # Funktion mit der wir immer die gleichen Zufallszahlen generieren können

np.transpose(my_np_array)                       #Array wird transponiert





#Indexing and Slicing
x = np.array([[1, 2], [3, 4], [5, 6]])
#[x,y]                                          x = Reihe, y = Spalte, durch Komma getrennt
#start:stop[:step]                              #Start ist inklusiv, Stop ist exklusiv, Step ist optional
print(x[:3])                                    #Alle Zeilen (0,1,2 deren Index kleiner als 3 ist)  
print(x[1:])                                    #Alle Zeilen Index>=1
print(x[1:2])                                   #Zeilen Index >=1 && Index<2
print(x[::-1])                                  #Alle Zeilen umgedrehte Reihenfolge
print(x[::2])                                   #Wenn Zeilenindex durch Zwei Teilbar ist, wird die Zeile ausgegeben
print(x[::2,::2])                               #Wenn Zeilenindex durch zwei Teilbar ist, wird jeder Spaltenindex der durch Zwei in dieser Zeile ist ausgegeben
print(B[1::2])                                  #Jede zweiten Zeile inklusive der ersten werden ausgegeben
print(x[0, :])                                  #Zeile Index 0, Alle 
print(x[0])                                     #Alle Werte in Zeile 0                                     
print(x[:, 0])                                  #Nur den ersten Wert in jeder Zeile
print(np.count_nonzero(M<0))                    #Zählt/Anzahl wie viele Werte kleiner als 0 im Array M sind
x[x>2]=-1                                       #Alle Werte die Größer als 2 sind werden mit -1 befüllt
print(x)

y=np.multiply(2,x)                              #Multiplizieren einer Matrix mit einem Faktor

i=np.tril_indices(2,-1)                         #numpy.tril_indices(n, k=0) n=Dimension des Arrays, k=Der Offset um den Schräge nach unten verschoben wird, 0=Mitte
N[i]=-1                                         #In N werden die zwei Arrays, die in i sind übergeben und die Werte auf -1 gesetzt
                                                #l für lower

i=np.triu_indices(3,1)                          #tril_indices bloß für die obere Hälfte, u für upper
N[i]=1

#Ufunctions
from typing import Iterable
import numpy as np

x = np.arange(4)
print(x + 2)                                    #In Array X wird jeder Wert um 2 erhöht
print(x - 2)                                    #In Array X wird jeder Wert um 2 verrringert
print(x * 2)                                    #In Array X wird jeder Wert mit 2 multipliziert             
print(x / 2)                                    #In Array X wird jeder Wert durch 2 geteilt
print(np.add(x, 2))                             #In Array X wird jeder Wert um 2 erhöht
print(np.abs(x))                                #Der absolute Wert jeder Zahl wird ausgegeben
print(fabs(x))                                  #float absolut
print(np.linspace(0,5,10))                      #Zahlen werden gleichmäßig verteilt; start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0)
print(np.sin())                                 #Sinus wird berechnet
print(np.cos())                                 #Cosinus wird berechnet
print(np.greater([4, 2], [2, 2]))               #Die einzelnen Werte werden miteinander verglichen und True oder False ausgegeben
